# %%
from glob import glob 
import pandas as pd
result_root_dir = "/workspace/pcos_dataset/results/multi/baseline_변경라벨"
test_files = glob(f"{result_root_dir}/test_fold_*/test_metrics.csv")
test_files
# Out:
# ['/workspace/pcos_dataset/results/multi/baseline_변경라벨/test_fold_2/test_metrics.csv',
#  '/workspace/pcos_dataset/results/multi/baseline_변경라벨/test_fold_3/test_metrics.csv',
#  '/workspace/pcos_dataset/results/multi/baseline_변경라벨/test_fold_0/test_metrics.csv',
#  '/workspace/pcos_dataset/results/multi/baseline_변경라벨/test_fold_4/test_metrics.csv',
#  '/workspace/pcos_dataset/results/multi/baseline_변경라벨/test_fold_1/test_metrics.csv']

# %%
from IPython.display import display
test_dict = {}
for file in test_files:
    fold = file.split("/")[-2]
    df = pd.read_csv(file)
    test_dict[fold] = df


# 첫번째 칼럼에 key값 들어가기
test_df = pd.concat(
    [df.assign(fold=key.split("_")[-1]) for key, df in test_dict.items()],
    ignore_index=True
)
test_df = test_df[['fold'] + [col for col in test_df.columns if col != 'fold']]

display(test_df[['fold', 'eval_accuracy', 'eval_f1_macro', 'eval_precision_macro', 'eval_recall_macro']].round(3))
# Out:
#   fold  eval_accuracy  eval_f1_macro  eval_precision_macro  eval_recall_macro
# 0    2          0.692          0.439                 0.473              0.432
# 1    3          0.663          0.400                 0.426              0.396
# 2    0          0.660          0.377                 0.383              0.384
# 3    4          0.704          0.454                 0.498              0.443
# 4    1          0.692          0.398                 0.438              0.401
