# %%
#!/usr/bin/env python
import sys
import os
sys.path.append('../')
from model.loader import model_Loader
import importlib
# MODEL_LIST = [
#     "alexnet", "convnext", "dynamic-vit", "inception", "mobilenet", "resnet", "vgg",
#     "densenet", "efficient", "ocys-net", "swin-transformer", "yolo", "vision-transformer",
# ]

# %%
base_model = model_Loader(model_name = 'swin-transformer'
# Out:
# Model 'swin-transformer' loaded.
# <bound method Module.parameters of binary_model(
#   (base_model): SwinTransformer(
#     (patch_embed): PatchEmbed(
#       (proj): Conv2d(3, 96, kernel_size=(4, 4), stride=(4, 4))
#       (norm): LayerNorm((96,), eps=1e-05, elementwise_affine=True)
#     )
#     (layers): Sequential(
#       (0): SwinTransformerStage(
#         (downsample): Identity()
#         (blocks): Sequential(
#           (0): SwinTransformerBlock(
#             (norm1): LayerNorm((96,), eps=1e-05, elementwise_affine=True)
#             (attn): WindowAttention(
#               (qkv): Linear(in_features=96, out_features=288, bias=True)
#               (attn_drop): Dropout(p=0.0, inplace=False)
#               (proj): Linear(in_features=96, out_features=96, bias=True)
#               (proj_drop): Dropout(p=0.0, inplace=False)
#               (softmax): Softmax(dim=-1)
#             )
#             (drop_path1): Identity()
# ...

# %%
from torchvision import models 
model =  models.convnext_large(weights = models.ConvNeXt_Large_Weights.IMAGENET1K_V1)

model

# %%
model.classifier[-1].in_features

# %%
from torchvision import models
base_model =  models.vit_l_16(weights = models.ViT_L_16_Weights.IMAGENET1K_V1)
base_model

# %%
import torch.nn as nn 
base_model.heads[-1] = nn.Linear(base_model.heads.head.in_features, 1)
base_model

# %% [markdown]
# # USFM 모델 Seg model 가지고 와서 인코더 부분만 추출해 분류 모델로 사용
